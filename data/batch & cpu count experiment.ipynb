# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Batch size experiment.csv")
data_times = pd.read_csv("Batch size experiment times.csv")
print(data.shape)
data
# Out:
# (3960, 12)
#       wins  wins_without_guess  time_elapsed  samples_considered  \
# 0       10                  10      0.390595                  27
# 1       10                   9      0.453089                  39
# 2        9                   9      0.499958                  32
# 3        8                   8      0.609323                  39
# 4       10                  10      0.421949                  31
# ...    ...                 ...           ...                 ...
# 3955   177                  72   1615.032455                9635
# 3956   160                  67   1440.321970                9708
# 3957   186                  78   1082.275299                9738
# 3958   193                  79   1199.917265                9856
# 3959   170                  60   1086.978126                9508
#
#       samples_with_solutions      difficulty sample_size  \
# 0                         27  Beginner (9x9)       11x11
# 1                         37  Beginner (9x9)       11x11
# 2                         31  Beginner (9x9)       11x11
# 3                         37  Beginner (9x9)       11x11
# 4                         31  Beginner (9x9)       11x11
# ...                      ...             ...         ...
# 3955                    8526  Expert (16x30)       18x32
# 3956                    8653  Expert (16x30)       18x32
# 3957                    8742  Expert (16x30)       18x32
# 3958                    8778  Expert (16x30)       18x32
# 3959                    8399  Expert (16x30)       18x32
#
#       use_num_mines_constraint first_click_pos  first_click_is_zero  \
# 0                         True          (3, 3)                 True
# 1                         True          (3, 3)                 True
# 2                         True          (3, 3)                 True
# 3                         True          (3, 3)                 True
# 4                         True          (3, 3)                 True
# ...                        ...             ...                  ...
# 3955                      True          (3, 3)                 True
# 3956                      True          (3, 3)                 True
# 3957                      True          (3, 3)                 True
# 3958                      True          (3, 3)                 True
# 3959                      True          (3, 3)                 True
#
#       parameters_id  batch_size
# 0                 1          10
# 1                 1          10
# 2                 1          10
# 3                 1          10
# 4                 1          10
# ...             ...         ...
# 3955              3         500
# 3956              3         500
# 3957              3         500
# 3958              3         500
# 3959              3         500
#
# [3960 rows x 12 columns]

# %%
print(data_times.shape)
data_times
# Out:
# (6, 2)
#    batch_size  time_elapsed
# 0          10   2584.907562
# 1          25   2604.046351
# 2          50   2651.810141
# 3         100   2682.542370
# 4         250   2725.840438
# 5         500   2970.516882
